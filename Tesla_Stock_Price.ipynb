# %%
import math
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")

import keras
from keras.models import Sequential
from keras.callbacks import EarlyStopping
from keras.layers import Dense, LSTM, Dropout

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
data_dir = 'Tesla.csv'
df = pd.read_csv(data_dir, parse_dates= True , index_col= "Date")

# %%
df.head()
# Out:
#                  Open   High        Low      Close    Volume  Adj Close
# Date
# 2010-06-29  19.000000  25.00  17.540001  23.889999  18766300  23.889999
# 2010-06-30  25.790001  30.42  23.299999  23.830000  17187100  23.830000
# 2010-07-01  25.000000  25.92  20.270000  21.959999   8218800  21.959999
# 2010-07-02  23.000000  23.10  18.709999  19.200001   5139800  19.200001
# 2010-07-06  20.000000  20.00  15.830000  16.110001   6866900  16.110001

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1692 entries, 2010-06-29 to 2017-03-17
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1692 non-null   float64
#  1   High       1692 non-null   float64
#  2   Low        1692 non-null   float64
#  3   Close      1692 non-null   float64
#  4   Volume     1692 non-null   int64
#  5   Adj Close  1692 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 92.5 KB

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1692.000000  1692.000000  1692.000000  1692.000000  1.692000e+03
# mean    132.441572   134.769698   129.996223   132.428658  4.270741e+06
# std      94.309923    95.694914    92.855227    94.313187  4.295971e+06
# min      16.139999    16.629999    14.980000    15.800000  1.185000e+05
# 25%      30.000000    30.650000    29.215000    29.884999  1.194350e+06
# 50%     156.334999   162.370002   153.150002   158.160004  3.180700e+06
# 75%     220.557495   224.099999   217.119999   220.022503  5.662100e+06
# max     287.670013   291.420013   280.399994   286.040009  3.716390e+07
#
#          Adj Close
# count  1692.000000
# mean    132.428658
# std      94.313187
# min      15.800000
# 25%      29.884999
# 50%     158.160004
# 75%     220.022503
# max     286.040009

# %%
plt.figure(figsize=(15, 6))
df['Open'].plot()
df['Close'].plot()
plt.ylabel(None)
plt.xlabel(None)
plt.title("Opening & Closing Price of Tesla")
plt.legend(['Open Price', 'Close Price'])
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 6))
df['Volume'].plot()
plt.ylabel('Volume')
plt.xlabel(None)
plt.title("Sales Volume of Tesla")
plt.tight_layout()
plt.show()

# %%
# We'll use pct_change to find the percent change for each day
plt.figure(figsize=(15, 6))
df['Adj Close'].pct_change().hist(bins=50)
plt.ylabel('Daily Return')
plt.title(f'Tesla Dialy Return')
plt.tight_layout()
plt.show()

# %%
dataset = df["Close"]
dataset = pd.DataFrame(dataset)

data = dataset.values

data.shape
# Out:
# (1692, 1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range= (0, 1))
scaled_data = scaler.fit_transform(np.array(data).reshape(-1, 1))

# %%
# 75% to Train , 25% to Test
train_size = int(len(data)*.75)
test_size = len(data) - train_size

print("Train Size :",train_size,"Test Size :",test_size)

train_data = scaled_data[ :train_size , 0:1 ]
test_data = scaled_data[ train_size-60: , 0:1 ]
# Out:
# Train Size : 1269 Test Size : 423

# %%
train_data.shape, test_data.shape
# Out:
# ((1269, 1), (483, 1))

# %%
# Creating a Training set with 60 time-steps and 1 output
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])

# %%
# Convert to numpy array
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
# Reshaping the input
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
x_train.shape , y_train.shape
# Out:
# ((1209, 60, 1), (1209,))

# %%
model = Sequential([
    LSTM(50, return_sequences= True, input_shape= (x_train.shape[1], 1)),
    LSTM(64, return_sequences= False),
    Dense(32),
    Dense(16),
    Dense(1)
])

model.compile(optimizer= 'adam', loss= 'mse' , metrics= "mean_absolute_error")

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 50)            10400
#
#  lstm_1 (LSTM)               (None, 64)                29440
#
#  dense (Dense)               (None, 32)                2080
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 42465 (165.88 KB)
# Trainable params: 42465 (165.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
# Fitting the LSTM to the Training set
callbacks = [EarlyStopping(monitor= 'loss', patience= 10 , restore_best_weights= True)]
history = model.fit(x_train, y_train, epochs= 100, batch_size= 32 , callbacks= callbacks )
# Out:
# Epoch 1/100
# 38/38 [==============================] - 6s 27ms/step - loss: 0.0156 - mean_absolute_error: 0.0764
# Epoch 2/100
# 38/38 [==============================] - 1s 26ms/step - loss: 0.0012 - mean_absolute_error: 0.0221
# Epoch 3/100
# 38/38 [==============================] - 1s 26ms/step - loss: 0.0011 - mean_absolute_error: 0.0209
# Epoch 4/100
# 38/38 [==============================] - 1s 25ms/step - loss: 0.0010 - mean_absolute_error: 0.0203
# Epoch 5/100
# 38/38 [==============================] - 1s 25ms/step - loss: 0.0010 - mean_absolute_error: 0.0201
# Epoch 6/100
# 38/38 [==============================] - 1s 25ms/step - loss: 9.9494e-04 - mean_absolute_error: 0.0205
# Epoch 7/100
# 38/38 [==============================] - 1s 25ms/step - loss: 9.4827e-04 - mean_absolute_error: 0.0196
# Epoch 8/100
# 38/38 [==============================] - 1s 25ms/step - loss: 8.6073e-04 - mean_absolute_error: 0.0187
# Epoch 9/100
# 38/38 [==============================] - 1s 25ms/step - loss: 8.4530e-04 - mean_absolute_error: 0.0186
# Epoch 10/100
# 38/38 [==============================] - 1s 25ms/step - loss: 7.8690e-04 - mean_absolute_error: 0.0181
# Epoch 11/100
# 38/38 [==============================] - 1s 25ms/step - loss: 7.4276e-04 - mean_absolute_error: 0.0174
# Epoch 12/100
# 38/38 [==============================] - 1s 25ms/step - loss: 7.7026e-04 - mean_absolute_error: 0.0177
# Epoch 13/100
# 38/38 [==============================] - 1s 25ms/step - loss: 7.3686e-04 - mean_absolute_error: 0.0176
# Epoch 14/100
# 38/38 [==============================] - 1s 25ms/step - loss: 8.0642e-04 - mean_absolute_error: 0.0186
# Epoch 15/100
# 38/38 [==============================] - 1s 26ms/step - loss: 7.8454e-04 - mean_absolute_error: 0.0182
# Epoch 16/100
# 38/38 [==============================] - 1s 25ms/step - loss: 8.5528e-04 - mean_absolute_error: 0.0195
# Epoch 17/100
# 38/38 [==============================] - 1s 25ms/step - loss: 0.0010 - mean_absolute_error: 0.0218
# Epoch 18/100
# 38/38 [==============================] - 1s 27ms/step - loss: 6.4655e-04 - mean_absolute_error: 0.0165
# Epoch 19/100
# 38/38 [==============================] - 1s 27ms/step - loss: 6.2577e-04 - mean_absolute_error: 0.0159
# Epoch 20/100
# 38/38 [==============================] - 1s 25ms/step - loss: 9.6170e-04 - mean_absolute_error: 0.0200
# Epoch 21/100
# 38/38 [==============================] - 1s 25ms/step - loss: 6.4166e-04 - mean_absolute_error: 0.0162
# Epoch 22/100
# 38/38 [==============================] - 1s 25ms/step - loss: 7.2083e-04 - mean_absolute_error: 0.0179
# Epoch 23/100
# 38/38 [==============================] - 1s 25ms/step - loss: 7.3826e-04 - mean_absolute_error: 0.0181
# Epoch 24/100
# 38/38 [==============================] - 1s 26ms/step - loss: 6.7052e-04 - mean_absolute_error: 0.0168
# Epoch 25/100
# 38/38 [==============================] - 1s 25ms/step - loss: 6.4883e-04 - mean_absolute_error: 0.0167
# Epoch 26/100
# 38/38 [==============================] - 1s 25ms/step - loss: 5.4690e-04 - mean_absolute_error: 0.0152
# Epoch 27/100
# 38/38 [==============================] - 1s 25ms/step - loss: 5.5108e-04 - mean_absolute_error: 0.0150
# Epoch 28/100
# 38/38 [==============================] - 1s 25ms/step - loss: 5.3721e-04 - mean_absolute_error: 0.0146
# Epoch 29/100
# 38/38 [==============================] - 1s 26ms/step - loss: 5.3292e-04 - mean_absolute_error: 0.0150
# Epoch 30/100
# 38/38 [==============================] - 1s 26ms/step - loss: 5.7128e-04 - mean_absolute_error: 0.0154
# Epoch 31/100
# 38/38 [==============================] - 1s 25ms/step - loss: 5.4635e-04 - mean_absolute_error: 0.0155
# Epoch 32/100
# 38/38 [==============================] - 1s 25ms/step - loss: 4.7803e-04 - mean_absolute_error: 0.0138
# Epoch 33/100
# 38/38 [==============================] - 1s 25ms/step - loss: 6.1952e-04 - mean_absolute_error: 0.0160
# Epoch 34/100
# 38/38 [==============================] - 1s 26ms/step - loss: 4.7435e-04 - mean_absolute_error: 0.0138
# Epoch 35/100
# 38/38 [==============================] - 1s 27ms/step - loss: 4.8524e-04 - mean_absolute_error: 0.0142
# Epoch 36/100
# 38/38 [==============================] - 1s 26ms/step - loss: 5.0383e-04 - mean_absolute_error: 0.0139
# Epoch 37/100
# 38/38 [==============================] - 1s 25ms/step - loss: 5.1694e-04 - mean_absolute_error: 0.0145
# Epoch 38/100
# 38/38 [==============================] - 1s 25ms/step - loss: 4.6525e-04 - mean_absolute_error: 0.0140
# Epoch 39/100
# 38/38 [==============================] - 1s 26ms/step - loss: 4.5708e-04 - mean_absolute_error: 0.0133
# Epoch 40/100
# 38/38 [==============================] - 1s 25ms/step - loss: 4.6040e-04 - mean_absolute_error: 0.0135
# Epoch 41/100
# 38/38 [==============================] - 1s 25ms/step - loss: 4.2566e-04 - mean_absolute_error: 0.0132
# Epoch 42/100
# 38/38 [==============================] - 1s 25ms/step - loss: 3.9209e-04 - mean_absolute_error: 0.0121
# Epoch 43/100
# 38/38 [==============================] - 1s 25ms/step - loss: 3.8216e-04 - mean_absolute_error: 0.0120
# Epoch 44/100
# 38/38 [==============================] - 1s 25ms/step - loss: 4.9758e-04 - mean_absolute_error: 0.0140
# Epoch 45/100
# 38/38 [==============================] - 1s 25ms/step - loss: 4.4185e-04 - mean_absolute_error: 0.0134
# Epoch 46/100
# 38/38 [==============================] - 1s 25ms/step - loss: 4.9859e-04 - mean_absolute_error: 0.0146
# Epoch 47/100
# 38/38 [==============================] - 1s 26ms/step - loss: 3.7014e-04 - mean_absolute_error: 0.0118
# Epoch 48/100
# 38/38 [==============================] - 1s 26ms/step - loss: 4.3860e-04 - mean_absolute_error: 0.0131
# Epoch 49/100
# 38/38 [==============================] - 1s 25ms/step - loss: 5.6211e-04 - mean_absolute_error: 0.0157
# Epoch 50/100
# 38/38 [==============================] - 1s 26ms/step - loss: 3.7854e-04 - mean_absolute_error: 0.0121
# Epoch 51/100
# 38/38 [==============================] - 1s 27ms/step - loss: 3.6308e-04 - mean_absolute_error: 0.0114
# Epoch 52/100
# 38/38 [==============================] - 1s 27ms/step - loss: 4.0752e-04 - mean_absolute_error: 0.0131
# Epoch 53/100
# 38/38 [==============================] - 1s 25ms/step - loss: 4.5282e-04 - mean_absolute_error: 0.0137
# Epoch 54/100
# 38/38 [==============================] - 1s 25ms/step - loss: 3.4845e-04 - mean_absolute_error: 0.0117
# Epoch 55/100
# 38/38 [==============================] - 1s 25ms/step - loss: 3.5725e-04 - mean_absolute_error: 0.0120
# Epoch 56/100
# 38/38 [==============================] - 1s 25ms/step - loss: 4.4895e-04 - mean_absolute_error: 0.0140
# Epoch 57/100
# 38/38 [==============================] - 1s 25ms/step - loss: 3.7815e-04 - mean_absolute_error: 0.0118
# Epoch 58/100
# 38/38 [==============================] - 1s 25ms/step - loss: 3.1991e-04 - mean_absolute_error: 0.0107
# Epoch 59/100
# 38/38 [==============================] - 1s 25ms/step - loss: 3.4570e-04 - mean_absolute_error: 0.0116
# Epoch 60/100
# 38/38 [==============================] - 1s 25ms/step - loss: 3.3544e-04 - mean_absolute_error: 0.0117
# Epoch 61/100
# 38/38 [==============================] - 1s 25ms/step - loss: 3.5476e-04 - mean_absolute_error: 0.0116
# Epoch 62/100
# 38/38 [==============================] - 1s 25ms/step - loss: 3.1740e-04 - mean_absolute_error: 0.0109
# Epoch 63/100
# 38/38 [==============================] - 1s 25ms/step - loss: 3.0552e-04 - mean_absolute_error: 0.0107
# Epoch 64/100
# 38/38 [==============================] - 1s 25ms/step - loss: 3.4699e-04 - mean_absolute_error: 0.0118
# Epoch 65/100
# 38/38 [==============================] - 1s 25ms/step - loss: 3.0672e-04 - mean_absolute_error: 0.0109
# Epoch 66/100
# 38/38 [==============================] - 1s 25ms/step - loss: 4.0165e-04 - mean_absolute_error: 0.0127
# Epoch 67/100
# 38/38 [==============================] - 1s 27ms/step - loss: 2.8857e-04 - mean_absolute_error: 0.0102
# Epoch 68/100
# 38/38 [==============================] - 1s 26ms/step - loss: 3.5712e-04 - mean_absolute_error: 0.0122
# Epoch 69/100
# 38/38 [==============================] - 1s 26ms/step - loss: 3.9546e-04 - mean_absolute_error: 0.0134
# Epoch 70/100
# 38/38 [==============================] - 1s 25ms/step - loss: 3.9844e-04 - mean_absolute_error: 0.0130
# Epoch 71/100
# 38/38 [==============================] - 1s 25ms/step - loss: 3.1052e-04 - mean_absolute_error: 0.0113
# Epoch 72/100
# 38/38 [==============================] - 1s 25ms/step - loss: 3.5765e-04 - mean_absolute_error: 0.0125
# Epoch 73/100
# 38/38 [==============================] - 1s 25ms/step - loss: 3.0878e-04 - mean_absolute_error: 0.0110
# Epoch 74/100
# 38/38 [==============================] - 1s 25ms/step - loss: 2.9561e-04 - mean_absolute_error: 0.0107
# Epoch 75/100
# 38/38 [==============================] - 1s 25ms/step - loss: 2.9810e-04 - mean_absolute_error: 0.0108
# Epoch 76/100
# 38/38 [==============================] - 1s 25ms/step - loss: 3.2601e-04 - mean_absolute_error: 0.0114
# Epoch 77/100
# 38/38 [==============================] - 1s 26ms/step - loss: 3.1592e-04 - mean_absolute_error: 0.0113

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["mean_absolute_error"])
plt.legend(['Mean Squared Error','Mean Absolute Error'])
plt.title("Losses")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# ## Predection

# %%
# Creating a testing set with 60 time-steps and 1 output
x_test = []
y_test = []

for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])
    y_test.append(test_data[i, 0])
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
x_test.shape , y_test.shape
# Out:
# ((423, 60, 1), (423,))

# %%
#inverse y_test scaling
predictions = model.predict(x_test)

#inverse predictions scaling
predictions = scaler.inverse_transform(predictions)
predictions.shape
# Out:
# 14/14 [==============================] - 1s 10ms/step
# (423, 1)

# %%
#inverse y_test scaling
y_test = scaler.inverse_transform([y_test])

RMSE = np.sqrt(np.mean( y_test - predictions )**2).round(2)
RMSE
# Out:
# 3.81

# %% [markdown]
# ### Visualize Predictions with The Data

# %%
train = dataset.iloc[:train_size , 0:1]
test = dataset.iloc[train_size: , 0:1]
test['Predictions'] = predictions

plt.figure(figsize= (16, 6))
plt.title('Tesla Close Stock Price Prediction', fontsize= 18)
plt.xlabel('Date', fontsize= 18)
plt.ylabel('Close Price', fontsize= 18)
plt.plot(train['Close'], linewidth= 3)
plt.plot(test['Close'], linewidth= 3)
plt.plot(test["Predictions"], linewidth= 3)
plt.legend(['Train', 'Test', 'Predictions'])
